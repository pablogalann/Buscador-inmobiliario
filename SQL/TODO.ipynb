# %%
import pandas as pd  # importación de pandas 
import numpy as np  # importacion de numpy 

pd.set_option('display.max_columns', None)  # mostrar todas las columnas del df 
pd.set_option('display.max_rows', None)   # mostrar todas las filas del df

import warnings  # importacion de bloqueo de errores
warnings.filterwarnings('ignore')

import pylab as plt    # visualización
import seaborn as sns    # visualización

# %matplotlib inline

# %% [markdown]
# ### ABRIR CSV LIMPIOS

# %%
mercados = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\01_tabla_mercados_csv.csv',encoding='latin1')

# %%
educacion = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\02_tabla_educacion2_csv.csv',encoding='latin1')

# %%
salud = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\03_tabla_centrosalud_csv.csv',encoding='latin1')

# %%
metro = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\04_tabla_metro_csv.csv',encoding='latin1')

# %%
zonasverdes = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\05_tabla_zonasverdes_csv.csv',encoding='latin1')

# %%
hoteles = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\06_tabla_hosteleria_csv.csv',encoding='latin1')

# %%
seguridad = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\07_tabla_comisarias_csv.csv',encoding='latin1')

# %%
cementerios = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\08_tabla_cementerio_csv.csv',encoding='latin1')

# %%
restauracion = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\09_tabla_restauracion_csv.csv',encoding='latin1')

# %%
comercios = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\10_tabla_comercio_csv.csv',encoding='latin1')

# %%
matrizbarrios = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\11_tabla_barrios_csv.csv',encoding='latin1')

# %%
inmobiliario = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\12_tabla_inmobiliario_csv.csv',encoding='latin1')

# %%
inmo_retiro = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\13_tabla_inmoretiro_csv.csv',encoding='latin1')

# %%
teatros = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\14_tabla_teatros_csv.csv',encoding='latin1')

# %%
cines = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\15_tabla_cines_csv.csv',encoding='latin1')

# %%
auditorios = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\csv_limpios\16_tabla_auditorios_csv.csv',encoding='latin1')

# %%
mercados.head()
# Out:
#    id_mercado                                       nombre_mer       barrio  \
# 0           0  Mercado municipal de San Fernando (Embajadores)  EMBAJADORES
# 1           1              Mercado municipal de AntÃ³n MartÃ­n  EMBAJADORES
# 2           2                   Mercado municipal de la Cebada      PALACIO
# 3           3                  Mercado municipal de San AntÃ³n     JUSTICIA
# 4           4                    Mercado municipal de BarcelÃ³     JUSTICIA
#
#    id_barrio distrito  id_distrito               direccion  num     CP  \
# 0        2.0   CENTRO          1.0       CALLE EMBAJADORES   41  28012
# 1        2.0   CENTRO          1.0      CALLE SANTA ISABEL    5  28012
# 2        1.0   CENTRO          1.0            PLAZA CEBADA   17  28005
# 3        4.0   CENTRO          1.0  CALLE AUGUSTO FIGUEROA   24  28004
# 4        4.0   CENTRO          1.0           CALLE BARCELO    6  28004
#
#    coordenada_x  coordenada_y    latitud  longitud
# 0      440274.0     4473236.0  40.407599 -3.703910
# 1      440710.0     4473658.0  40.411422 -3.698811
# 2      439780.0     4473650.0  40.411293 -3.709771
# 3      440825.0     4474835.0  40.422043 -3.697565
# 4      440683.0     4475365.0  40.426807 -3.699277

# %%
educacion.head()
# Out:
#    id_centro_edu                                         centro_edu  \
# 0              0              CENTRO DE INFANTIL Y PRIMARIA PUBLICO
# 1              1  ENSENANZA NO REGLADA (DEPORTIVA Y RECREATIVA, ...
# 2              2  CENTRO PUBLICO DE SECUNDARIA, BACHILLERATO Y/O FP
# 3              3  ENSENANZA NO REGLADA (DEPORTIVA Y RECREATIVA, ...
# 4              4  ENSENANZA NO REGLADA (DEPORTIVA Y RECREATIVA, ...
#
#                tipo_edu Pub_Priv                barrio  id_barrio  \
# 0   INFANTIL Y PRIMARIA  PUBLICO  EMBAJADORES                   2
# 1            NO REGLADA  PRIVADO  EMBAJADORES                   2
# 2  SECUNDARIA, BACH, FP  PUBLICO  UNIVERSIDAD                   5
# 3            NO REGLADA  PRIVADO  UNIVERSIDAD                   5
# 4            NO REGLADA  PRIVADO  UNIVERSIDAD                   5
#
#                distrito  id_distrito  \
# 0  CENTRO                          1
# 1  CENTRO                          1
# 2  CENTRO                          1
# 3  CENTRO                          1
# 4  CENTRO                          1
#
#                                            direccion  num  coordenada_x  \
# 0  CALLE                    VENTORRILLO          ...   14      440134.6
# 1  CALLE                    SOMBRERETE           ...   12      440399.6
# 2  CALLE                    PALMA                ...   46      440111.6
# 3  CALLE                    PEZ                  ...   12      440215.6
# 4  CALLE                    ESPIRITU SANTO       ...   23      440229.6
#
#    coordenada_y    latitud  longitud
# 0     4473142.5  40.406745 -3.705532
# 1     4473338.5  40.408530 -3.702428
# 2     4475344.5  40.426580 -3.706010
# 3     4474986.5  40.423363 -3.704751
# 4     4475220.5  40.425472 -3.704608

# %%
salud.head()
# Out:
#    id_centro_salud                                      nombre_centro  \
# 0                0  Centro de AtenciÃ³n integral sociosanitaria no...
# 1                1                       Centro Joven de Madrid Salud
# 2                2  Hospital de la Venerable Orden Tercera de San ...
# 3                3                        Centro de Salud Palma Norte
# 4                4  CMSc Centro Municipal de Salud Comunitaria Centro
#
#   tipo_centro       barrio  id_barrio distrito  id_distrito  \
# 0     C.SALUD     JUSTICIA        4.0   CENTRO          1.0
# 1     C.SALUD          SOL        6.0   CENTRO          1.0
# 2    HOSPITAL      PALACIO        1.0   CENTRO          1.0
# 3     C.SALUD  UNIVERSIDAD        5.0   CENTRO          1.0
# 4     C.SALUD          SOL        6.0   CENTRO          1.0
#
#                          direccion   num       CP  coordenada_x  coordenada_y  \
# 0  CALLE HERMANOS ALVAREZ QUINTERO   3.0  28004.0        440835       4475437
# 1            CALLE NAVAS DE TOLOSA  10.0  28013.0        440025       4474530
# 2                CALLE SAN BERNABE  13.0  28005.0        439424       4473404
# 3                      CALLE PALMA  59.0  28015.0        439995       4475350
# 4            CALLE NAVAS DE TOLOSA  10.0  28013.0        440026       4474527
#
#      latitud  longitud
# 0  40.427474 -3.697485
# 1  40.419229 -3.706954
# 2  40.409051 -3.713943
# 3  40.426623 -3.707385
# 4  40.419202 -3.706942

# %%
metro.head()
# Out:
#    id_estacion nombre_estacion    barrio  id_barrio distrito  id_distrito  \
# 0            0           Opera   PALACIO          1   CENTRO            1
# 1            1          Chueca  JUSTICIA          4   CENTRO            1
# 2            2          Callao       SOL          6   CENTRO            1
# 3            3             Sol       SOL          6   CENTRO            1
# 4            4          Bilbao  JUSTICIA          4   CENTRO            1
#
#    orden_paradas     trafico      latitud      longitud
# 0             14  14.850.637  40,41823746  -3,709330457
# 1             18   3.039.046   40,4225677   -3,69764598
# 2              5  15.303.823  40,42026238  -3,705670266
# 3             15  49.567.085  40,41686834  -3,702793213
# 4             12   8.467.553  40,42903458  -3,702228731

# %%
zonasverdes.head()
# Out:
#    id_zonaverde                             nombre_zv       barrio  id_barrio  \
# 0             0                      PARQUE DE ATENAS      PALACIO          1
# 1             1            JARDINES ARQUITECTO RIBERA     JUSTICIA          4
# 2             2  JARDINES DE LA PZA. DE GABRIEL MIRÃ      PALACIO          1
# 3             3                MERCADO PTA. DE TOLEDO  EMBAJADORES          2
# 4             4                      TALUD C/ SEGOVIA      PALACIO          1
#
#   distrito  id_distrito Superficie (m2) Superficie (ha)
# 0   CENTRO            1       46.569,03            4,66
# 1   CENTRO            1        4.778,92            0,48
# 2   CENTRO            1        5.462,68            0,55
# 3   CENTRO            1        5.751,54            0,58
# 4   CENTRO            1        9.985,49            1,00

# %%
hoteles.head()
# Out:
#    id_alojamiento  tipo_alojamiento restaurante                barrio  \
# 0               0             HOTEL          SI  CORTES
# 1               1             HOTEL          NO  EMBAJADORES
# 2               2       APART-HOTEL          NO  JUSTICIA
# 3               3           PENSION          NO  PALACIO
# 4               5  ALBERGUE JUVENIL          NO  EMBAJADORES
#
#    id_barrio              distrito  id_distrito  \
# 0          3  CENTRO                          1
# 1          2  CENTRO                          1
# 2          4  CENTRO                          1
# 3          1  CENTRO                          1
# 4          2  CENTRO                          1
#
#                                            direccion  num  coordenada_x  \
# 0  PASEO                    PRADO                ...   48     441226.60
# 1  CALLE                    SANTA ISABEL         ...    4     440639.60
# 2  CALLE                    FUENCARRAL           ...   46     440566.28
# 3  CALLE                    CRUZADA              ...    1     439667.16
# 4  CALLE                    ATOCHA               ...   16     440285.60
#
#    coordenada_y    latitud  longitud
# 0     4473481.5  40.409877 -3.692695
# 1     4473735.5  40.412124 -3.699636
# 2     4474970.0  40.423239 -3.700616
# 3     4474213.5  40.416360 -3.711142
# 4     4473966.5  40.414179 -3.703830

# %%
seguridad.head()
# Out:
#    id_comisaria                                   nombre_comisaria    barrio  \
# 0             0             ComisarÃ­a de PolicÃ­a Madrid (Centro)   PALACIO
# 1             1             ComisarÃ­a de PolicÃ­a Madrid (Retiro)    CORTES
# 2             2         ComisarÃ­a de PolicÃ­a Madrid (Arganzuela)   ACACIAS
# 3             3          ComisarÃ­a de PolicÃ­a Madrid (Salamanca)      GOYA
# 4             4  ComisarÃ­a de PolicÃ­a y Oficina de TramitaciÃ...  CASTILLA
#
#    id_barrio    distrito  id_distrito                   direccion   num  \
# 0          1      CENTRO            1             CALLE LEGANITOS  19.0
# 1          3      CENTRO            1               CALLE HUERTAS  76.0
# 2          2  ARGANZUELA            2                RONDA TOLEDO  26.0
# 3          2   SALAMANCA            4  CALLE PRINCIPE DE ASTURIAS   8.0
# 4          6   CHAMARTIN            5             AVENIDA PIO XII  48.0
#
#       CP  coordenada_x  coordenada_y    latitud  longitud
# 0  28013        439756       4474787  40.421541 -3.710141
# 1  28014        441156       4474018  40.412851 -3.694972
# 2  28005        440082       4473001  40.405468 -3.706139
# 3  28006        443027       4475466  40.427881 -3.671666
# 4  28016        442950       4480048  40.469152 -3.672974

# %%
cementerios.head()
# Out:
#    id_cementerio                         nombre_cementerio      barrio  \
# 0              0             Cementerio Cristo de El Pardo    EL PARDO
# 1              1                    Cementerio de El Pardo    EL PARDO
# 2              2                  Cementerio de Fuencarral   EL GOLOSO
# 3              3                     Cementerio de Aravaca  VALDEMARIN
# 4              4  Cementerio BritÃ¡nico (British Cemetery)  SAN ISIDRO
#
#    id_barrio             distrito  id_distrito  \
# 0        1.0  FUENCARRAL-EL PARDO          8.0
# 1        1.0  FUENCARRAL-EL PARDO          8.0
# 2        8.0  FUENCARRAL-EL PARDO          8.0
# 3        5.0      MONCLOA-ARAVACA          9.0
# 4        3.0          CARABANCHEL         11.0
#
#                              direccion   num     CP  coordenada_x  \
# 0         CARRETERA CRISTO DE EL PARDO  11.0  28048        433197
# 1  CARRETERA EL PARDO A COLMENAR VIEJO  13.0  28048        433475
# 2                 AVENIDA MONTECARMELO  10.0  28049        440647
# 3                      CAMINO ZARZUELA  26.0  28023        433274
# 4            CALLE COMANDANTE FONTANES   7.0  28019        438673
#
#    coordenada_y    latitud  longitud
# 0       4485709  40.519412 -3.788610
# 1       4487635  40.536793 -3.785543
# 2       4484200  40.506385 -3.700539
# 3       4479751  40.465747 -3.787073
# 4       4471874  40.395213 -3.722634

# %%
restauracion.head()
# Out:
#    id_local       tipo_local                barrio  id_barrio  \
# 0         0  BAR RESTAURANTE  PALACIO                       1
# 1         3  BAR RESTAURANTE  JUSTICIA                      4
# 2         4  BAR RESTAURANTE  EMBAJADORES                   2
# 3         5        CAFETERIA  SOL                           6
# 4         6      RESTAURANTE  JUSTICIA                      4
#
#                distrito  id_distrito  \
# 0  CENTRO                          1
# 1  CENTRO                          1
# 2  CENTRO                          1
# 3  CENTRO                          1
# 4  CENTRO                          1
#
#                                            direccion  num  coordenada_x  \
# 0  PLAZA                    SANTO DOMINGO        ...   12      439844.6
# 1  CALLE                    GENERAL CASTANOS     ...   15      441155.6
# 2  CALLE                    MESON DE PAREDES     ...   52      440279.6
# 3  PLAZA                    CARMEN               ...    1      440317.6
# 4  PLAZA                    SALESAS              ...    7      441094.6
#
#    coordenada_y    latitud  longitud
# 0     4474692.5  40.420688 -3.709096
# 1     4475300.5  40.426259 -3.693700
# 2     4473426.5  40.409314 -3.703850
# 3     4474445.5  40.418497 -3.703498
# 4     4475021.5  40.423741 -3.694393

# %%
comercios.head()
# Out:
#    id_comercio             tipo_comercio                barrio  id_barrio  \
# 0            0                CARNICERIA  EMBAJADORES                   2
# 1            1                PERFUMERIA  SOL                           6
# 2            2                  LIBRERIA  EMBAJADORES                   2
# 3            3                     OTROS  SOL                           6
# 4            6  ARTICULOS ESPECIALIZADOS  JUSTICIA                      4
#
#                distrito  id_distrito  \
# 0  CENTRO                          1
# 1  CENTRO                          1
# 2  CENTRO                          1
# 3  CENTRO                          1
# 4  CENTRO                          1
#
#                                            direccion  num  coordenada_x  \
# 0  CALLE                    TOLEDO               ...   75      439852.6
# 1  CALLE                    POSTIGO DE SAN MARTIN...    9      440096.6
# 2  CALLE                    ESPERANZA            ...    5      440560.6
# 3  CALLE                    ESPARTEROS           ...   10      440165.6
# 4  CALLE                    MEJIA LEQUERICA      ...   16      440701.6
#
#    coordenada_y    latitud  longitud
# 0     4473567.5  40.410554 -3.708895
# 1     4474540.5  40.419337 -3.706112
# 2     4473528.5  40.410253 -3.700548
# 3     4474153.5  40.415855 -3.705262
# 4     4475431.5  40.427406 -3.699064

# %%
matrizbarrios.head()
# Out:
#         barrio  id_barrio  Superfie (km2)  Superficie (m2) distrito  \
# 0      PALACIO          1            1.47          1470000   CENTRO
# 1  EMBAJADORES          2            1.03          1030000   CENTRO
# 2       CORTES          3            0.59           590000   CENTRO
# 3     JUSTICIA          4            0.74           740000   CENTRO
# 4  UNIVERSIDAD          5            0.95           950000   CENTRO
#
#    id_distrito
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
inmobiliario.head()
# Out:
#    id_inmueble  precio  planta   int/ext  nÂº hab     m2  ascensor  garage  \
# 0            0  340000       1  EXTERIOR        2   67.0     False   False
# 1            1  245000       0  INTERIOR        2   90.0      True   False
# 2            2  850000       2  EXTERIOR        2  180.0     False   False
# 3            3  850000       1  EXTERIOR        2  110.0      True   False
# 4            4  950000       1  EXTERIOR        3  180.0      True   False
#
#         barrio  id_barrio distrito  id_distrito
# 0  EMBAJADORES          2   CENTRO            1
# 1       CORTES          3   CENTRO            1
# 2      PALACIO          1   CENTRO            1
# 3     JUSTICIA          4   CENTRO            1
# 4       CORTES          3   CENTRO            1

# %%
inmo_retiro.head()
# Out:
#    id_inmueble  precio  planta   int/ext  nÂº hab     m2  ascensor  garage  \
# 0            0  795000     6.0  EXTERIOR      3.0  155.0      True   False
# 1            1  630000     6.0  EXTERIOR      3.0  172.0     False   False
# 2            2  350000     6.0  EXTERIOR      3.0   83.0      True   False
# 3            3  630000     6.0  INTERIOR      3.0  185.0      True   False
# 4            4  630000     6.0  EXTERIOR      3.0  185.0     False   False
#
#      barrio  id_barrio distrito  id_distrito   latitud  longitud
# 0  PACIFICO          1   RETIRO            3  40.40660 -3.679014
# 1  PACIFICO          1   RETIRO            3  40.40324 -3.678011
# 2  PACIFICO          1   RETIRO            3  40.40386 -3.679942
# 3  PACIFICO          1   RETIRO            3  40.40262 -3.678651
# 4  PACIFICO          1   RETIRO            3  40.40279 -3.679443

# %%
teatros.head()
# Out:
#    id_teatro                                      nombre_teatro       barrio  \
# 0          0  Teatro de la Comedia. CompaÃ±Ã­a Nacional de T...       CORTES
# 1          1                                      Teatro Karpas  EMBAJADORES
# 2          2                              Teatro Infanta Isabel     JUSTICIA
# 3          3                 Teatro FÃ­garo - Adolfo Marsillach  EMBAJADORES
# 4          4                                    Teatro EspaÃ±ol       CORTES
#
#    id_barrio distrito  id_distrito             direccion   num     CP  \
# 0        3.0   CENTRO          1.0       CALLE PRÃNCIPE  14.0  28012
# 1        2.0   CENTRO          1.0    CALLE SANTA ISABEL  19.0  28012
# 2        4.0   CENTRO          1.0       CALLE BARQUILLO  24.0  28004
# 3        2.0   CENTRO          1.0  CALLE DOCTOR CORTEZO   5.0  28012
# 4        3.0   CENTRO          1.0        CALLE PRINCIPE  25.0  28012
#
#    coordenada_x  coordenada_y    latitud  longitud
# 0        440577       4474129  40.415665 -3.700411
# 1        440803       4473550  40.410456 -3.697705
# 2        440993       4474853  40.422217 -3.695587
# 3        440298       4473886  40.413456 -3.703676
# 4        440597       4474036  40.414829 -3.700166

# %%
cines.head()
# Out:
#    id_cine                            nombre_cine       barrio  id_barrio  \
# 0        0                           Cines Callao          SOL          6
# 1        1                      Yelmo Cines Ideal  EMBAJADORES          2
# 2        2                 Cine Capitol Gran VÃ­a      PALACIO          1
# 3        3        Filmoteca EspaÃ±ola. Cine DorÃ©  EMBAJADORES          2
# 4        4  Cine Estudio CÃ­rculo de Bellas Artes       CORTES          3
#
#   distrito  id_distrito             direccion   num     CP  coordenada_x  \
# 0   CENTRO            1          PLAZA CALLAO   3.0  28013        440150
# 1   CENTRO            1  CALLE DOCTOR CORTEZO   6.0  28012        440287
# 2   CENTRO            1        CALLE GRAN VIA  41.0  28013        440057
# 3   CENTRO            1    CALLE SANTA ISABEL   3.0  28012        440675
# 4   CENTRO            1          CALLE ALCALA  42.0  28014        440903
#
#    coordenada_y    latitud  longitud
# 0       4474615  40.420013 -3.705489
# 1       4473925  40.413812 -3.703800
# 2       4474664  40.420438 -3.706590
# 3       4473701  40.411807 -3.699228
# 4       4474433  40.418418 -3.696608

# %%
cines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_cine       30 non-null     int64
#  1   nombre_cine   30 non-null     object
#  2   barrio        30 non-null     object
#  3   id_barrio     30 non-null     int64
#  4   distrito      30 non-null     object
#  5   id_distrito   30 non-null     int64
#  6   direccion     30 non-null     object
#  7   num           30 non-null     float64
#  8   CP            30 non-null     int64
#  9   coordenada_x  30 non-null     int64
#  10  coordenada_y  30 non-null     int64
#  11  latitud       30 non-null     float64
#  12  longitud      30 non-null     float64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 3.2+ KB

# %%
auditorios.head()
# Out:
#    id_equip          nombre_equip       tipo_equip       barrio  id_barrio  \
# 0         0       Sala Maravillas  SALA CONCIERTOS  UNIVERSIDAD        5.0
# 1         1     Sala Beer Station  SALA CONCIERTOS      PALACIO        1.0
# 2         2        Sala Hangar 48  SALA CONCIERTOS      PALACIO        1.0
# 3         3  Sala Fulanita de tal  SALA CONCIERTOS     JUSTICIA        4.0
# 4         4       Sala FotomatÃ³n  SALA CONCIERTOS  UNIVERSIDAD        5.0
#
#   distrito  id_distrito                 direccion   num     CP  coordenada_x  \
# 0   CENTRO          1.0  CALLE SAN VICENTE FERRER  33.0  28004        440254
# 1   CENTRO          1.0      CUESTA SANTO DOMINGO  22.0  28013        439897
# 2   CENTRO          1.0              CALLE BAILEN  24.0  28005        439414
# 3   CENTRO          1.0            CALLE REGUEROS   9.0  28004        440920
# 4   CENTRO          1.0     PLAZA CONDE DE TORENO   2.0  28015        439811
#
#    coordenada_y    latitud  longitud                geometry
# 0       4475253  40.425768 -3.704319  POINT (440254 4475253)
# 1       4474584  40.419718 -3.708463  POINT (439897 4474584)
# 2       4473662  40.411376 -3.714064  POINT (439414 4473662)
# 3       4475127  40.424683 -3.696460  POINT (440920 4475127)
# 4       4475125  40.424590 -3.709522  POINT (439811 4475125)

# %%
auditorios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_equip      88 non-null     int64
#  1   nombre_equip  88 non-null     object
#  2   tipo_equip    88 non-null     object
#  3   barrio        88 non-null     object
#  4   id_barrio     88 non-null     float64
#  5   distrito      88 non-null     object
#  6   id_distrito   88 non-null     float64
#  7   direccion     88 non-null     object
#  8   num           88 non-null     float64
#  9   CP            88 non-null     int64
#  10  coordenada_x  88 non-null     int64
#  11  coordenada_y  88 non-null     int64
#  12  latitud       88 non-null     float64
#  13  longitud      88 non-null     float64
#  14  geometry      88 non-null     object
# dtypes: float64(5), int64(4), object(6)
# memory usage: 10.4+ KB

# %%
def limpiar_puntos(x):
    x2 = int(x)
    return x2.replace('.',',')

# %%
auditorios.latitud = auditorios.latitud.apply(limpiar_puntos)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 auditorios.latitud = auditorios.latitud.apply(limpiar_puntos)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\Anaconda3\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~\Anaconda3\lib\site-packages\pandas\core\apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [40], in limpiar_puntos(x)
#       1 def limpiar_puntos(x):
#       2     x2 = int(x)
# ----> 3     return x2.replace('.',',')
#
# AttributeError: 'int' object has no attribute 'replace'
