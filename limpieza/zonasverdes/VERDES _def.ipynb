# %%
import pandas as pd  # importación de pandas 
import numpy as np  # importacion de numpy 

pd.set_option('display.max_columns', None)  # mostrar todas las columnas del df 
pd.set_option('display.max_rows', None)   # mostrar todas las filas del df

import warnings  # importacion de bloqueo de errores
warnings.filterwarnings('ignore')

import pylab as plt    # visualización
import seaborn as sns    # visualización

# %matplotlib inline

# %%
zv = pd.read_csv(r'C:\Users\pablo\8.0 Proyecto final\limpieza\zonasverdes\tabla_zonasverdes_csv.csv', encoding='latin-1')

# %%
zv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 619 entries, 0 to 618
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_zonaverde     619 non-null    int64
#  1   nombre_zv        619 non-null    object
#  2   barrio           619 non-null    object
#  3   id_barrio        619 non-null    int64
#  4   distrito         619 non-null    object
#  5   id_distrito      619 non-null    int64
#  6   Superficie (m2)  619 non-null    object
#  7   Superficie (ha)  619 non-null    object
# dtypes: int64(3), object(5)
# memory usage: 38.8+ KB

# %%
zv.rename(columns = { 'Nº Distrito':'id_distrito','BARRIO':'barrio',
                      'DISTRITO':'distrito', 'PARQUES Y ZONAS VERDES DE DISTRITO CON MAYOR SUPERFICIE':'nombre_zv'}, inplace = True)

# %%
zv.shape
# Out:
# (619, 8)

# %%
zv
# Out:
#      id_zonaverde                                          nombre_zv  \
# 0               0                                   PARQUE DE ATENAS
# 1               1                         JARDINES ARQUITECTO RIBERA
# 2               2               JARDINES DE LA PZA. DE GABRIEL MIRÃ
# 3               3                             MERCADO PTA. DE TOLEDO
# 4               4                                   TALUD C/ SEGOVIA
# 5               5           JARDINES DE LA PZA. DE LA VILLA DE PARIS
# 6               6                                    JARDIN DE LARRA
# 7               7                          JARDINES DE LAS VISTILLAS
# 8               8                                 PÂº DE RECOLETOS I
# 9               9                          PARQUE CASINO DE LA REINA
# 10             10                               PARQUE DE LA CORNISA
# 11             11                                        PÂº PRADO I
# 12             12                               CUESTA DE LOS CIEGOS
# ...

# %%
def limpiar_acento(x):
    if 'Ã\x91' in x:
        return x.replace('Ã\x91','N')
    else:
        return x

# %%
zv.barrio = zv.barrio.apply(limpiar_acento)

# %%
id_barrio = []
id_distrito = []
barrio = []
for x in zv.barrio:
    
    if x  == 'PALACIO' :
        barrio = 'PALACIO'#
        id_distrito.append(1)
        id_barrio.append(11)
    elif x == 'CORTES':
        barrio = 'CORTES'#
        id_distrito.append(1)
        id_barrio.append(13)
    elif x =='EMBAJADORES':#
        barrio = 'EMBAJADORES'
        id_distrito.append(1)
        id_barrio.append(12)
    elif x == 'JUSTICIA':#
        barrio = 'JUSTICIA'
        id_distrito.append(1)
        id_barrio.append(14)
    elif x == 'SOL':
        barrio = 'SOL'
        id_distrito.append(1)
        id_barrio.append(16)
    elif x == 'UNIVERSIDAD':
        barrio = 'UNIVERSIDAD'
        id_distrito.append(1)
        id_barrio.append(14)
   
        #2
    elif x == 'IMPERIAL':#
        barrio = 'IMPERIAL'
        id_distrito.append(2)
        id_barrio.append(21)
    elif x =='ACACIAS' : #
        barrio = 'ACACIAS'
        id_distrito.append(2)
        id_barrio.append(22)
    elif x =='CHOPERA' :#
        barrio = 'CHOPERA'
        id_distrito.append(2)
        id_barrio.append(23)
    elif x  =='LEGAZPI' :#
        barrio = 'LEGAZPI'
        id_distrito.append(2)
        id_barrio.append(24)
    elif x=='DELICIAS' :#
        barrio = 'DELICIAS'
        id_distrito.append(2)
        id_barrio.append(25)
    elif x=='PALOS DE MOGUER' :#
        barrio = 'PALOS DE MOGUER'
        id_distrito.append(2)
        id_barrio.append(26)
    elif x=='ATOCHA' :# FALTA PALOS DE SU PUTA MADRE
        barrio = 'ATOCHA'
        id_distrito.append(2)
        id_barrio.append(27)
        
        #3
    elif x=='PACIFICO':#
        barrio = 'PACIFICO'
        id_distrito.append(3)
        id_barrio.append(31)    
    elif x=='ADELFAS':#
        barrio = 'ADELFAS'
        id_distrito.append(3)
        id_barrio.append(32)
    elif x== 'ESTRELLA' :#
        barrio = 'ESTRELLA'
        id_distrito.append(3)
        id_barrio.append(33)
    elif x=='IBIZA' :#
        barrio = 'IBIZA'
        id_distrito.append(3)
        id_barrio.append(34)
    elif x=='LOS JERONIMOS':#
        barrio = 'JERONIMOS'
        id_distrito.append(3)
        id_barrio.append(35)
    elif x=='JESUS':#
        barrio = 'NINO JESUS'
        id_distrito.append(3)
        id_barrio.append(36)
    
        #4
    elif x=='RECOLETOS' :#
        barrio = 'RECOLETOS'
        id_distrito.append(4)
        id_barrio.append(41)
    elif x=='GOYA' :#
        barrio = 'GOYA'
        id_distrito.append(4)
        id_barrio.append(42)
    elif x=='FUENTE DEL BERRO' :#
        barrio = 'FUENTE DEL BERRO'
        id_distrito.append(4)
        id_barrio.append(43)
    elif x=='GUINDALERA':#
        barrio = 'GUINDALERA'
        id_distrito.append(4)
        id_barrio.append(44)
    elif x=='LISTA':#
        barrio = 'LISTA'
        id_distrito.append(4)
        id_barrio.append(45)
    elif x=='CASTELLANA' :#
        barrio = 'CASTELLANA'
        id_distrito.append(4)
        id_barrio.append(46)
        #5
    elif x=='EL VISO':#
        barrio = 'EL VISO'
        id_distrito.append(5)
        id_barrio.append(51)
    elif x=='PROSPERIDAD':#
        barrio = 'PROSPERIDAD'
        id_distrito.append(5)
        id_barrio.append(52)
    elif x=='CIUDAD JARDIN':#
        barrio = 'CIUDAD JARDIN'
        id_distrito.append(5)
        id_barrio.append(53)
    elif x=='HISPANOAMERICA':#
        barrio = 'HISPANOAMERICA'
        id_distrito.append(5)
        id_barrio.append(54)
    elif x=='NUEVA ESPANA':#
        barrio = 'NUEVA ESPANA'
        id_distrito.append(5)
        id_barrio.append(55)
    elif x=='CASTILLA':#
        barrio = 'CASTILLA'
        id_distrito.append(5)
        id_barrio.append(56)
      #6  
    elif x== 'BUENAS VISTAS':#
        barrio = 'BUENAS VISTAS'
        id_distrito.append(6)
        id_barrio.append(61)
    elif x== 'CUATRO CAMINOS':#
        barrio = 'CUATRO CAMINOS'
        id_distrito.append(6)
        id_barrio.append(62)
    elif x== 'CASTILLEJOS':#
        barrio = 'CASTILLEJOS'
        id_distrito.append(6)
        id_barrio.append(63)
    elif x=='ALMENARA':#
        barrio = 'ALMENARA'
        id_distrito.append(6)
        id_barrio.append(64)
    elif x== 'VALDEACEDERAS':#
        barrio = 'VALDEACEDERAS'
        id_distrito.append(6)
        id_barrio.append(65)
    elif x=='BERRUGUETE':#
        barrio = 'BERRUGUETE'
        id_distrito.append(6)
        id_barrio.append(66)

       #7 
    elif x=='GAZTAMBIDE':#
        barrio = 'GAZTAMBIDE'
        id_distrito.append(7)
        id_barrio.append(71)
    elif x=='ARAPILES':#
        barrio = 'ARAPILES'
        id_distrito.append(7)
        id_barrio.append(72)
    elif x=='TRAFALGAR':#
        barrio = 'TRAFALGAR'
        id_distrito.append(7)
        id_barrio.append(73)
    elif x=='ALMAGRO':#
        barrio = 'ALMAGRO'
        id_distrito.append(7)
        id_barrio.append(74)
    elif x=='RIOS ROSAS':#
        barrio = 'RIOS ROSA'
        id_distrito.append(7)
        id_barrio.append(75)
    elif x=='VALLEHERMOSO':#
        barrio = 'VALLEHERMOSO'
        id_distrito.append(7)
        id_barrio.append(76)
       #8 
    elif x=='EL PARDO':#
        barrio = 'EL PARDO'
        id_distrito.append(8)
        id_barrio.append(81)
    elif x=='FUENTELARREINA':#
        barrio = 'FUENTELARREINA'
        id_distrito.append(8)
        id_barrio.append(82)
    elif x=='PENA GRANDE':#
        barrio = 'PENAGRANDE'
        id_distrito.append(8)
        id_barrio.append(83)
    elif x=='EL PILAR':#
        barrio = 'PILAR'
        id_distrito.append(8)
        id_barrio.append(84)
    elif x=='LA PAZ':#
        barrio = 'LA PAZ'
        id_distrito.append(8)
        id_barrio.append(85)
    elif x=='VALVERDE':#
        barrio = 'VALVERDE'
        id_distrito.append(8)
        id_barrio.append(86)
    elif x=='MIRASIERRA':#
        barrio = 'MIRASIERRA'
        id_distrito.append(8)
        id_barrio.append(87)
    elif x=='EL GOLOSO':#
        barrio = 'EL GOLOSO'
        id_distrito.append(8)
        id_barrio.append(88)
      #9  
    elif x=='CASA DE CAMPO'  :#
        barrio = 'CASA DE CAMPO'
        id_distrito.append(9)
        id_barrio.append(91)
    elif x=='ARGUELLES' :#
        barrio = 'ARGUELLES'
        id_distrito.append(9)
        id_barrio.append(92)
    elif x=='CIUDAD UNIVERSITARIA' :#
        barrio = 'CIUDAD UNIVERSITARIA'
        id_distrito.append(9)
        id_barrio.append(93)
    elif x=='VALDEZARZA' :#
        barrio = 'VALDEZARZA'
        id_distrito.append(9)
        id_barrio.append(94)
    elif x=='VALDEMARIN' :#
        barrio = 'VALDEMARIN'
        id_distrito.append(9)
        id_barrio.append(95)
    elif x=='EL PLANTIO' :#
        barrio = 'EL PLANTIO'
        id_distrito.append(9)
        id_barrio.append(96)
    elif x=='ARAVACA' :#
        barrio = 'ARAVACA'
        id_distrito.append(9)
        id_barrio.append(97)
     #10   
    elif x=='LOS CARMENES'  :#
        barrio = 'LOS CARMENES'
        id_distrito.append(10)
        id_barrio.append(101)
    elif x=='PUERTA DEL ANGEL' :#
        barrio = 'PUERTA DEL ANGEL'
        id_distrito.append(10)
        id_barrio.append(102)
    elif x=='LUCERO' :#
        barrio = 'LUCERO'
        id_distrito.append(10)
        id_barrio.append(103)
    elif x=='ALUCHE' :#
        barrio = 'ALUCHE'
        id_distrito.append(10)
        id_barrio.append(104)
    elif x=='CAMPAMENTO' :#
        barrio = 'CAMPAMENTO'
        id_distrito.append(10)
        id_barrio.append(105)
    elif x=='CUATRO VIENTOS' :#
        barrio = 'CUATRO VIENTOS'
        id_distrito.append(10)
        id_barrio.append(106)
    elif x=='LAS AGUILAS' :#
        barrio = 'LAS AGUILAS'
        id_distrito.append(10)
        id_barrio.append(107)
    #11    
    elif x=='COMILLAS' :#
        barrio = 'COMILLAS'
        id_distrito.append(11)
        id_barrio.append(111)
    elif x=='OPANEL':#
        barrio = 'OPANEL'
        id_distrito.append(11)
        id_barrio.append(112)
    elif x=='SAN ISIDRO':#
        barrio = 'SAN ISIDRO'
        id_distrito.append(11)
        id_barrio.append(113)
    elif x=='VISTA ALEGRE':#
        barrio = 'VISTA ALEGRE'
        id_distrito.append(11)
        id_barrio.append(114)
    elif x=='PUERTA BONITA':#
        barrio = 'PUERTA BONITA'
        id_distrito.append(11)
        id_barrio.append(115)
    elif x=='BUENAVISTA':#
        barrio = 'BUENAVISTA'
        id_distrito.append(11)
        id_barrio.append(116)
    elif x=='ABRANTES':#
        barrio = 'ABRANTES'
        id_distrito.append(11)
        id_barrio.append(117)
     #12   
    elif x=='ORCASITAS' :#
        barrio = 'ORCASITAS'
        id_distrito.append(12)
        id_barrio.append(121)
    elif x=='ORCASUR':#
        barrio = 'ORCASUR'
        id_distrito.append(12)
        id_barrio.append(122)
    elif x=='SAN FERMIN':#
        barrio = 'SAN FERMIN'
        id_distrito.append(12)
        id_barrio.append(123)
    elif x=='ALMENDRALES':#
        barrio = 'ALMENDRALES'
        id_distrito.append(12)
        id_barrio.append(124)
    elif x=='MOSCARDO':#
        barrio = 'MOSCARDO'
        id_distrito.append(12)
        id_barrio.append(125)
    elif x=='ZOFIO':#
        barrio = 'ZOFIO'
        id_distrito.append(12)
        id_barrio.append(126)
    elif x=='PRADOLONGO':#
        barrio = 'PRADOLONGO'
        id_distrito.append(12)
        id_barrio.append(127)
    #13    
    if x=='ENTREVIAS' :#
        barrio = 'ENTREVIAS'
        id_distrito.append(13)
        id_barrio.append(131)
    elif x=='SAN DIEGO':#
        barrio = 'SAN DIEGO'
        id_distrito.append(13)
        id_barrio.append(132)
    elif x=='PALOMERAS SURESTE':#
        barrio = 'PALOMERAS SURESTE'
        id_distrito.append(13)
        id_barrio.append(133)
    elif x=='PALOMERAS BAJAS':#
        barrio = 'PALOMERAS BAJAS'
        id_distrito.append(13)
        id_barrio.append(134)
    elif x=='PORTAZGO':#
        barrio = 'PORTAZGO'
        id_distrito.append(13)
        id_barrio.append(135)
    elif x=='NUMANCIA':#
        barrio = 'NUMANCIA'
        id_distrito.append(13)
        id_barrio.append(136)
    #14    
    elif x=='PAVONES':#
        barrio = 'PAVONES'
        id_distrito.append(14)
        id_barrio.append(141)
    elif x=='HORCAJO':#
        barrio = 'HORCAJO'
        id_distrito.append(14)
        id_barrio.append(142)
    elif x=='MARROQUINA':#
        barrio = 'MARROQUINA'
        id_distrito.append(14)
        id_barrio.append(143)
    elif x=='MEDIA LEGUA':#
        barrio = 'MEDIA LEGUA'
        id_distrito.append(14)
        id_barrio.append(144)
    elif x=='FONTARRON':#
        barrio = 'FONTARRON'
        id_distrito.append(14)
        id_barrio.append(145)
    elif x=='VINATEROS':#
        barrio = 'VINATEROS'
        id_distrito.append(14)
        id_barrio.append(146)
     #15   
    elif x=='VENTAS' :#
        barrio = 'VENTAS'
        id_distrito.append(15)
        id_barrio.append(151)
    elif x== 'PUEBLO NUEVO':#
        barrio = 'PUEBLO NUEVO'
        id_distrito.append(15)
        id_barrio.append(152)
    elif x=='QUINTANA':#
        barrio = 'QUINTANA'
        id_distrito.append(15)
        id_barrio.append(153)
    elif  x=='CONCEPCION':#
        barrio = 'CONCEPCION'
        id_distrito.append(15)
        id_barrio.append(154)
    elif x== 'SAN PASCUAL':#
        id_barrio.append(155)
        barrio = 'SAN PASCUAL'
        id_distrito.append(15)
    elif x== 'SAN JUAN BAUTISTA':
        barrio = 'SAN JUAN BAUTISTA'
        id_distrito.append(15)
        id_barrio.append(156)
    elif x== 'COLINA':#
        barrio = 'COLINA'
        id_distrito.append(15)
        id_barrio.append(157)
    elif x=='ATALAYA':#
        barrio = 'ATALAYA'
        id_distrito.append(15)
        id_barrio.append(158)
    elif x== 'COSTILLARES':#
        barrio = 'COSTILLARES'
        id_distrito.append(15)
        id_barrio.append(159)
     #16   
    elif x=='PALOMAS' :#
        barrio = 'PALOMAS'
        id_distrito.append(16)
        id_barrio.append(1)
    elif x=='PIOVERA':#
        barrio = 'PIOVERA'
        id_distrito.append(16)
        id_barrio.append(162)
    elif x== 'CANILLAS':#
        barrio = 'CANILLAS'
        id_distrito.append(16)
        id_barrio.append(163)
    elif x=='PINAR DEL REY':#
        barrio = 'PINAR DEL REY'
        id_distrito.append(16)
        id_barrio.append(164)
    elif  x=='APOSTOL SANTIAGO':#
        barrio = 'APOSTOL SANTIAGO'
        id_distrito.append(16)
        id_barrio.append(165)
    elif x=='VALDEFUENTES': #
        barrio = 'VALDEFUENTES'
        id_distrito.append(16)
        id_barrio.append(166)
     #17   
    elif x=='VILLAVERDE ALTO C.H.':#
        barrio = 'CASCO HISTORICO DE VILLAVERDE'
        id_distrito.append(17)
        id_barrio.append(171)
    elif x== 'SAN CRISTOBAL':#
        barrio = 'SAN CRISTOBAL'
        id_distrito.append(17)
        id_barrio.append(172)
    elif  x=='BUTARQUE':#
        barrio = 'BUTARQUE'
        id_distrito.append(17)
        id_barrio.append(173)
    elif x== 'LOS ROSALES':#
        barrio = 'LOS ROSALES'
        id_distrito.append(17)
        id_barrio.append(174)
    elif x== 'LOS ANGELES':#
        barrio = 'LOS ANGELES'
        id_distrito.append(17)
        id_barrio.append(175)
    #18    
    elif x=='CASCO H.VALLECAS' :#
        barrio = 'CASCO HISTORICO VALLECAS'
        id_distrito.append(18)
        id_barrio.append(181)
    elif x=='SANTA EUGENIA':#
        barrio = 'SANTA EUGENIA'
        id_distrito.append(18)
        id_barrio.append(182)
    elif x=='ENSANCHE DE VALLECAS':#
        barrio = 'ENSANCHE DE VALLECAS'
        id_distrito.append(18)
        id_barrio.append(183)
    #19    
    elif x=='CASCO H.VICALVARO':#
        barrio = 'CASCO HISTORICO VICALVARO'
        id_distrito.append(19)
        id_barrio.append(191)
    elif x=='VALDEBERNARDO':#
        barrio = 'VALDEBERNARDO'
        id_distrito.append(19)
        id_barrio.append(192)
    elif x=='VALDERRIVAS':#
        barrio = 'VALDERRIVAS'
        id_distrito.append(19)
        id_barrio.append(193)
    elif x=='EL CANAVERAL':#
        barrio = 'EL CANAVERAL'
        id_distrito.append(19)
        id_barrio.append(194)
    #20    
    elif x=='SIMANCAS' :
        barrio = 'SIMANCAS'
        id_distrito.append(20)
        id_barrio.append(201)
    elif x=='HELLIN':#
        barrio = 'HELLIN'
        id_distrito.append(20)                 
        id_barrio.append(202)
    elif x=='AMPOSTA':
        barrio = 'AMPOSTA'
        id_distrito.append(20)                   
        id_barrio.append(203)
    elif x=='ARCOS':
        barrio = 'ARCOS'
        id_distrito.append(20)                   
        id_barrio.append(204)
    elif x=='ROSAS':
        barrio = 'ROSAS'
        id_distrito.append(20)                   
        id_barrio.append(205)
    elif x=='REJAS':#
        barrio = 'REJAS'
        id_distrito.append(20)                   
        id_barrio.append(206)
    elif x=='CANILLEJAS':
        barrio = 'CANILLEJAS'
        id_distrito.append(20)                   
        id_barrio.append(207)
    elif x== 'EL SALVADOR':
        barrio = 'EL SALVADOR'
        id_distrito.append(20)                 
        id_barrio.append(208)
    #21    
    elif x== 'ALAMEDA DE OSUNA':
        barrio = 'ALAMEDA DE OSUNA'
        id_distrito.append(21)
        id_barrio.append(211)
    elif x=='AEROPUERTO':
        barrio = 'AEROPUERTO'
        id_distrito.append(21)
        id_barrio.append(212)
    elif x=='AMPOSTA':
        barrio = 'AMPOSTA'
        id_distrito.append(21)
        id_barrio.append(213)
    elif x=='CASCO H.BARAJAS':
        barrio = 'CASCO HISTORICO BARAJAS'
        id_distrito.append(21)
        id_barrio.append(214)
    elif x=='TIMON':
        barrio = 'TIMON'
        id_distrito.append(21)
        id_barrio.append(215)
    elif x=='CORRALEJOS':
        barrio = 'CORRALEJOS'
        id_distrito.append(21)
        id_barrio.append(216)
len(id_barrio)
# Out:
# 619

# %%
zv['id_barrio'] = id_barrio

# %%
zv
# Out:
#      id_zonaverde                                          nombre_zv  \
# 0               0                                   PARQUE DE ATENAS
# 1               1                         JARDINES ARQUITECTO RIBERA
# 2               2               JARDINES DE LA PZA. DE GABRIEL MIRÃ
# 3               3                             MERCADO PTA. DE TOLEDO
# 4               4                                   TALUD C/ SEGOVIA
# 5               5           JARDINES DE LA PZA. DE LA VILLA DE PARIS
# 6               6                                    JARDIN DE LARRA
# 7               7                          JARDINES DE LAS VISTILLAS
# 8               8                                 PÂº DE RECOLETOS I
# 9               9                          PARQUE CASINO DE LA REINA
# 10             10                               PARQUE DE LA CORNISA
# 11             11                                        PÂº PRADO I
# 12             12                               CUESTA DE LOS CIEGOS
# ...

# %% [markdown]
# ### EXPORTAR A CSV

# %%
zv.to_csv('tabla_zonasverdes_csv.csv', encoding='utf-8',index = False)
